# %% [markdown]
# <a href="https://colab.research.google.com/github/BramanTyamahedrawan/PCVK-SMT-5/blob/main/Tugas_Kelompok_Pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **KELOMPOK 1**
#
#
# 1.   Braman Tyamahendrawan
# 2.   Diwa Arsyad Atthoriq
# 3.   Muhammad Maulana Givari

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/MyDrive/PCVK/pertemuan2/Salinan KTP.jpeg'
img = cv.imread (path)

img = cv.resize(img, (0, 0), fx=0.5, fy=0.5)

cv.rectangle(img, pt1=(92,33), pt2=(275,52), color=(0,255,0), thickness=cv.FILLED)

cv.rectangle(img, pt1=(92,55), pt2=(220,70), color=(255,0,0), thickness=cv.FILLED)

img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
import cv2 as cv
import matplotlib.pyplot as plt

path = '/content/drive/MyDrive/PCVK/pertemuan2/Salinan KTP.jpeg'
img = cv.imread(path)

img = cv.resize(img, (0, 0), fx=0.5, fy=0.5)

x1, y1, x2, y2 = 92, 33, 275, 52
cv.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), thickness=cv.FILLED)

x1, y1, x2, y2 = 92, 55, 220, 70
cv.rectangle(img, (x1, y1), (x2, y2), (255, 0, 0), thickness=cv.FILLED)

img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()
